# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Tasks" data-toc-modified-id="Tasks-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Tasks</a></span></li><li><span><a href="#scatter-1" data-toc-modified-id="scatter-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>scatter-1</a></span></li><li><span><a href="#scatter-2" data-toc-modified-id="scatter-2-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>scatter-2</a></span></li><li><span><a href="#scatter-3" data-toc-modified-id="scatter-3-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>scatter-3</a></span></li><li><span><a href="#scatter-4" data-toc-modified-id="scatter-4-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>scatter-4</a></span></li><li><span><a href="#barplots" data-toc-modified-id="barplots-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>barplots</a></span></li><li><span><a href="#histplot" data-toc-modified-id="histplot-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>histplot</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('diamonds.csv', index_col=0)
df['price_log'] = np.log(df['price'])
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_log
# 1   5.786897
# 2   5.786897
# 3   5.789960
# 4   5.811141
# 5   5.814131

# %% [markdown]
# # Tasks
# - Seaborn is highy recommended to use in order to solve the tasks, but you should google for examples in this library, but you still use the other libraries
# - Examples of expected charts are left for reference
# ---
#
# 1. Plot a scatter chart for carat and price
# 2. Plot previous chart again, but change scale of X and Y to logarithmic scale
# 3. Plot previous chart again, but color each point with respect to color of a diamond
# 4. Create new column transforming each color to integer number (0:D for white, ..., 6:H for the most yellow), then plor previous chart again
# 5. Plot bar chart for average price in dependence of cut
# 6. Plot bar chart for median price in dependence of cut
# 7. Put both previous chart on one picture. Is property between price and cut the same?
# 8. Put histogram of price distribution for premium and ideal diamonds and put them on the same plot. Scale histograms to look nice!

# %% [markdown]
# # scatter-1
# 1. Plot a scatter chart for carat and price

# %%
## your code

# %% [markdown]
# # scatter-2
# Plot previous chart again, but change scale of X and Y to logarithmic scale

# %%
## your code

# %% [markdown]
# # scatter-3
# 3. Plot previous chart again, but color each point with respect to color of a diamond

# %%
## your code

# %% [markdown]
# # scatter-4
# 4. Create new column transforming each color to integer number (0:D for white, ..., 6:H for the most yellow), then plor previous chart again

# %%
## your code

# %%
## your code

# %% [markdown]
# # barplots
#
# 5. Plot bar chart for average price in dependence of cut
# 6. Plot bar chart for median price in dependence of cut
# 7. Put both previous chart on one picture. Is property between price and cut the same?

# %%
## your code

# %% [markdown]
# # histplot
# 8. Put histogram of price distribution for premium and ideal diamonds and put them on the same plot. Scale histograms to look nice!

# %%
## your code
