# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#A-small-manual-on-the-main-charts-in-seaborn" data-toc-modified-id="A-small-manual-on-the-main-charts-in-seaborn-1">A small manual on the main charts in seaborn</a></span><ul class="toc-item"><li><span><a href="#1.1-Quantitative" data-toc-modified-id="1.1-Quantitative-1.1">1.1 Quantitative</a></span><ul class="toc-item"><li><span><a href="#histplot-,-kdeplot" data-toc-modified-id="histplot-,-kdeplot-1.1.1"><code>histplot</code> , <code>kdeplot</code></a></span></li><li><span><a href="#rugplot" data-toc-modified-id="rugplot-1.1.2"><code>rugplot</code></a></span></li><li><span><a href="#boxplot" data-toc-modified-id="boxplot-1.1.3"><code>boxplot</code></a></span></li></ul></li><li><span><a href="#1.2-Categorical" data-toc-modified-id="1.2-Categorical-1.2">1.2 Categorical</a></span><ul class="toc-item"><li><span><a href="#countplot" data-toc-modified-id="countplot-1.2.1"><code>countplot</code></a></span></li></ul></li><li><span><a href="#2.1-Quantitative-with-quantitative" data-toc-modified-id="2.1-Quantitative-with-quantitative-1.3">2.1 Quantitative with quantitative</a></span><ul class="toc-item"><li><span><a href="#kdeplot" data-toc-modified-id="kdeplot-1.3.1"><code>kdeplot</code></a></span></li><li><span><a href="#jointplot" data-toc-modified-id="jointplot-1.3.2"><code>jointplot</code></a></span></li></ul></li><li><span><a href="#2.2-Quantitative-with-categorical" data-toc-modified-id="2.2-Quantitative-with-categorical-1.4">2.2 Quantitative with categorical</a></span><ul class="toc-item"><li><span><a href="#barplot" data-toc-modified-id="barplot-1.4.1"><code>barplot</code></a></span></li><li><span><a href="#boxplot" data-toc-modified-id="boxplot-1.4.2"><code>boxplot</code></a></span></li><li><span><a href="#violinplot" data-toc-modified-id="violinplot-1.4.3"><code>violinplot</code></a></span></li><li><span><a href="#stripplot-,-swarmplot" data-toc-modified-id="stripplot-,-swarmplot-1.4.4"><code>stripplot</code> , <code>swarmplot</code></a></span></li></ul></li><li><span><a href="#2.3-Combinations-of-all-features-in-the-sample" data-toc-modified-id="2.3-Combinations-of-all-features-in-the-sample-1.5">2.3 Combinations of all features in the sample</a></span><ul class="toc-item"><li><span><a href="#pairplot" data-toc-modified-id="pairplot-1.5.1"><code>pairplot</code></a></span></li><li><span><a href="#PairGrid" data-toc-modified-id="PairGrid-1.5.2"><code>PairGrid</code></a></span></li></ul></li><li><span><a href="#2.4-Quantitative-and-somewhat-categorical" data-toc-modified-id="2.4-Quantitative-and-somewhat-categorical-1.6">2.4 Quantitative and somewhat categorical</a></span><ul class="toc-item"><li><span><a href="#Facet-Grid" data-toc-modified-id="Facet-Grid-1.6.1"><code>Facet Grid</code></a></span></li></ul></li><li><span><a href="#3.-Matrix-graphs" data-toc-modified-id="3.-Matrix-graphs-1.7">3. Matrix graphs</a></span></li></ul></li></ul></div>

# %% [markdown]
# # A small manual on the main charts in seaborn

# %%
import numpy as np # library for matrices and mathematics
import pandas as pd # library for working with tables

# libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')    # chart style
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Next, we will use the built-in data set about tips.

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# There are many different plotting functions in the Matplotlib and Seaborn libraries for data visualization. We have already studied that variables can be quantitative and categorical. It's very good if you know how to distinguish them. Depending on the types of variables, there are their own charting functions. Let's look at the most frequently used ones on specific data.

# %% [markdown]
# ## 1.1 Quantitative

# %% [markdown]
# Quantitative features can be displayed with the following useful functions:
# * `histplot`
# * `kdeplot`
# * `rugplot`
# * `boxplot`

# %% [markdown]
# ### `histplot` , `kdeplot`

# %% [markdown]
# 'histplot` with the parameter 'kde=True' shows a histogram and a graph of the distribution density

# %%
sns.histplot(x=tips['total_bill']);

# %%
sns.histplot(data=tips, x='total_bill', kde=True);

# %% [markdown]
# We can only look at the density using the `kdeplot` function

# %%
sns.kdeplot(tips['total_bill']);

# %% [markdown]
# ### `rugplot`

# %% [markdown]
# 'rugplot' shows the same as the distribution density graph, only in one-dimensional form. The denser the lines are, the higher the density.

# %%
sns.rugplot(tips['total_bill']);

# %% [markdown]
# For clarity` 'rugplot' is often useful to use with other types of graphs.

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill']);

# %% [markdown]
# ### `boxplot`

# %% [markdown]
# <center>
# <img src="https://github.com/hse-econ-data-science/dap_2021_spring/blob/main/sem10_visual/images/boxplot.png?raw=true" height="400" width="700">
# </center>

# %%
x = tips['total_bill'].values.copy()
x.sort()

# %%
[np.quantile(x, q) for q in [0.25, 0.5, 0.75]]
# Out:
# [13.3475, 17.795, 24.127499999999998]

# %%
x
# Out:
# array([ 3.07,  5.75,  7.25,  7.25,  7.51,  7.56,  7.74,  8.35,  8.51,
#         8.52,  8.58,  8.77,  9.55,  9.6 ,  9.68,  9.78,  9.94, 10.07,
#        10.07, 10.09, 10.27, 10.29, 10.33, 10.33, 10.34, 10.34, 10.51,
#        10.59, 10.63, 10.65, 10.77, 11.02, 11.17, 11.24, 11.35, 11.38,
#        11.59, 11.61, 11.69, 11.87, 12.02, 12.03, 12.16, 12.26, 12.43,
#        12.46, 12.48, 12.54, 12.6 , 12.66, 12.69, 12.74, 12.76, 12.9 ,
#        13.  , 13.  , 13.03, 13.13, 13.16, 13.27, 13.28, 13.37, 13.39,
#        13.42, 13.42, 13.42, 13.51, 13.81, 13.81, 13.94, 14.  , 14.07,
#        14.15, 14.26, 14.31, 14.48, 14.52, 14.73, 14.78, 14.83, 15.01,
#        15.04, 15.06, 15.36, 15.38, 15.42, 15.48, 15.53, 15.69, 15.69,
#        15.77, 15.81, 15.95, 15.98, 15.98, 16.  , 16.04, 16.21, 16.27,
#        16.29, 16.31, 16.32, 16.4 , 16.43, 16.45, 16.47, 16.49, 16.58,
#        16.66, 16.82, 16.93, 16.97, 16.99, 17.07, 17.26, 17.29, 17.31,
# ...

# %%
# using plt.subplot
plt.subplot(2,1,1)
sns.boxplot(tips['total_bill'], color='b')

plt.subplot(2,1,2)
sns.histplot(tips['total_bill'], kde=True, color='b');

# %%
# using fig, ax
fig, ax = plt.subplots(2,1)

sns.boxplot(tips['total_bill'], color='b', ax=ax[0])
sns.histplot(tips['total_bill'], kde=True, color='b', ax=ax[1]);

# %% [markdown]
# ## 1.2 Categorical

# %% [markdown]
# ### `countplot`

# %% [markdown]
# We count the number of values in each category.

# %%
tips['sex'].value_counts().plot(kind='bar');

# %%
#sns.countplot(tips['sex']);
sns.countplot(data=tips, x='sex');

# %% [markdown]
# ## 2.1 Quantitative with quantitative

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip');

# %%
# add trend to the graph
sns.regplot(data=tips, x='total_bill', y='tip');

# %%
# the other function
sns.lmplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# ### `kdeplot`

# %%
sns.kdeplot(data=tips, x='total_bill', y='tip');

# %% [markdown]
# ### `jointplot`

# %% [markdown]
# "joint plot' shows a joint distribution across two variables. It has a `kind' parameter, which can take the following values:
# * `scatter`
# * `reg`
# * `resid`
# * `kde`
# * `hex`

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter');

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg');

# %%
sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = 'kde');

# %%
sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = 'hex');

# %% [markdown]
# ## 2.2 Quantitative with categorical

# %% [markdown]
# ### `barplot`

# %% [markdown]
# "barplot' aggregates data by the values of a categorical variable and applies a certain function to the values of the corresponding groups of a quantitative variable. By default, this is the **average** function, but this function can be changed in the `estimator` parameter

# %%
tips.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips);

# %%
tips.groupby('sex')['total_bill'].median()
# Out:
# sex
# Female    16.40
# Male      18.35
# Name: total_bill, dtype: float64

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips, estimator = np.median);

# %% [markdown]
# ### `boxplot`

# %% [markdown]
# And again, the `boxplot' function we are already considering. With the interaction of features, this function can be many times more useful, since everything is clearer in comparison!

# %%
sns.boxplot(x='day', y='total_bill', data=tips);

# %% [markdown]
# For convenience, you can flip

# %%
sns.boxplot(x = 'total_bill', y = 'day', data = tips, orient = 'h');

# %% [markdown]
# Is it possible to open the third dimension in this way at all

# %%
sns.boxplot(x = 'day', y = 'total_bill', hue = 'smoker', data = tips);

# %% [markdown]
# ### `violinplot`

# %% [markdown]
# Performs the same function as 'boxplot'. In fact, these are two distribution density graphs rotated by 90 and -90 degrees, stuck together, resulting in something similar to a cello, hence the name.

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips);

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex');

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True);

# %% [markdown]
# ### `stripplot` , `swarmplot`

# %% [markdown]
# The 'strip plot' draws a scatter plot consisting of a single categorical variable.

# %%
sns.stripplot(data = tips, x = 'day', y = 'total_bill');

# %%
sns.stripplot(data = tips, x = 'day', y = 'total_bill', jitter = True, hue = 'sex');

# %%
sns.stripplot(data = tips, x = 'day', y = 'total_bill', jitter = True, hue = 'sex', dodge = True);

# %% [markdown]
# 'swarmplot' shows exactly the same thing, only the dots don't overlap

# %%
sns.swarmplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex', dodge = True);

# %% [markdown]
# Sometimes it is useful to combine these graphs with 'violinplot`

# %%
sns.violinplot(data = tips, x = 'tip', y = 'day', palette = 'rainbow')
sns.swarmplot(data = tips, x = 'tip', y = 'day', size = 3);

# %% [markdown]
# ## 2.3 Combinations of all features in the sample

# %% [markdown]
# ### `pairplot`

# %% [markdown]
# 'pairplot' shows the relationship between all pairs of variables. On the diagonal there are histograms, and in other places there are scatter diagrams.

# %%
sns.pairplot(tips);

# %%
sns.pairplot(tips, hue = 'sex');

# %% [markdown]
# ### `PairGrid`

# %% [markdown]
# "Pairgrid` is a more advanced function that allows you to show the relationship between all pairs of parameters for various functions. In fact, `pairplot' is a special case of it.

# %%
sns.PairGrid(tips);

# %%
g = sns.PairGrid(tips)
g.map(plt.scatter);

# %%
g = sns.PairGrid(tips)

g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot);

# %% [markdown]
# ## 2.4 Quantitative and somewhat categorical

# %% [markdown]
# ### `Facet Grid`
# 'FacetGrid' allows you to visualize the joint distribution of individual features of several variables

# %%
g = sns.FacetGrid(tips, col = 'time', row = 'smoker');

# %%
g = sns.FacetGrid(tips, col = 'time', row = 'smoker');
g = g.map(plt.hist, 'total_bill');

# %%
g = sns.FacetGrid(tips, col = 'time', row = 'smoker', hue = 'sex');
g = g.map(plt.scatter, 'total_bill', 'tip').add_legend();

# %% [markdown]
# ## 3. Matrix graphs

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot=True, vmax=1, vmin=-1, cmap='vlag');

# %%
flights = pd.read_csv('flights.csv')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# Let's calculate the conjugacy table, which will show what number of passengers flew in different months in each of the years in the interval from 1949 to 1960.

# %%
pvflights = flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
pvflights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# ...

# %%
sns.heatmap(pvflights, linecolor = 'white', linewidths = 1, cmap = 'magma');

# %%
sns.clustermap(pvflights);
